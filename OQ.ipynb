# %%
# %%capture
# !pip install openquake.engine

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fcc555f9-e9e6-4f0f-8c06-fd6003349e4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcc555f9-e9e6-4f0f-8c06-fd6003349e4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving job_EventBasedPSHA_GDrive.ini to job_EventBasedPSHA_GDrive (1).ini
# Saving HawkesBay_site-model.xml to HawkesBay_site-model (1).xml
# Saving gmpe_logic_tree-HikSubduction.xml to gmpe_logic_tree-HikSubduction (1).xml
# Saving source_model_hik-current-geom_Alex_3pts.xml to source_model_hik-current-geom_Alex_3pts (1).xml
# Saving source_model_logic_tree.xml to source_model_logic_tree (1).xml

# %%
# !oq engine --run job_EventBasedPSHA_GDrive.ini --exports csv
# Out:
# [2021-03-29 06:56:53 #1 INFO] root running /content/job_EventBasedPSHA_GDrive.ini [--hc=None]
# [2021-03-29 06:56:53 #1 INFO] Using engine version 3.11.3
# [2021-03-29 06:56:53 #1 WARNING] Using 2 cores on f89871450fa5
# [2021-03-29 06:56:53 #1 INFO] Validated source_model_logic_tree.xml in 0.00 seconds
# [2021-03-29 06:56:53 #1 INFO] Checksum of the input files: 1361717544
# [2021-03-29 06:56:53 #1 INFO] Reading the risk model if present
# [2021-03-29 06:56:53 #1 INFO] Extracting the hazard sites from the site model
# [2021-03-29 06:56:55 #1 INFO] Read N=15878 hazard sites and L=29 hazard levels
# [2021-03-29 06:56:56 #1 INFO] Total number of logic tree paths = 4
# [2021-03-29 06:56:56 #1 INFO] Reading the source model(s) in parallel
# [2021-03-29 06:56:56 #1 INFO] read_source_model 100% [1 submitted, 0 queued]
# [2021-03-29 06:56:56 #1 INFO] Received {'/content/source_model_hik-current-geom_Alex_3pts.xml': '2.16 KB'} in 0 seconds
# ...
